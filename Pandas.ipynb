# %%
import numpy ans np
import pandas as pd

# %%
import numpy as np
import pandas as pd
dict1={
    'name':['harry','rohan','saif','shub'],
    'marks':[92,34,45,19],
    'city':['rampur','kolkata','bihar','jaipur']
}
# df=pd.DataFrame(dict1)
# print(df)
df.to_csv('friends_idx_false.csv',index=False)
print(df.head(2))#show first 2 rows
print(df.tail(2))#show last row
print(df.describe())
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata
#    name  marks    city
# 2  saif     45   bihar
# 3  shub     19  jaipur
#            marks
# count   4.000000
# mean   47.500000
# std    31.522479
# min    19.000000
# 25%    30.250000
# 50%    39.500000
# 75%    56.750000
# max    92.000000

# %%
import numpy as np
import pandas as pd
harry=pd.read_csv('friends.csv')
# print(harry['name'][2])
harry.index=['first','second','third','fourth']
print(harry)
# Out:
#         Unnamed: 0   name  marks     city
# first            0  harry     92   rampur
# second           1  rohan     34  kolkata
# third            2   saif     45    bihar
# fourth           3   shub     19   jaipur

# %%
import numpy as np
import pandas as pd
ser=pd.Series(np.random.rand(12))
print(ser)
# Out:
# 0     0.282202
# 1     0.993037
# 2     0.855950
# 3     0.329229
# 4     0.648248
# 5     0.050798
# 6     0.470386
# 7     0.420274
# 8     0.140478
# 9     0.753009
# 10    0.744955
# 11    0.695788
# dtype: float64

# %%
import numpy as np
import pandas as pd
newdf=pd.DataFrame(np.random.rand(334,5))
# print(newdf.describe())
# newdf[0][0]="harry"
# print(newdf.head())
# print(newdf.T)#transpose
# print(newdf.head())
newdf.loc[0,0]=567;#chNGE THE value at this position
newdf.loc[0,3]=456;
newdf.columns=list('ABCDE')
# print(newdf)
# dj=newdf.loc[[1,2],['C','D']]
# print(dj)
# print(newdf.loc[(newdf['C']<0.4) &(newdf['C']>0.1)])
# print(newdf.head())
# print(newdf.iloc[0,4])# iloc start from 0 index always
# print(newdf.loc[1]['D'])
# print(newdf.iloc[[0,1],[1,2]])
# newdf=newdf.drop(['A','C'],axis=1)
# print(newdf)
newdf=newdf['B'].isnull()
print(newdf)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: B, Length: 334, dtype: bool

# %%
import numpy as np
import pandas as pd
data=pd.read_excel('Data Analytics.xlsx')
print(data)
data.to_excel('example.xlsx)
# print(data.iloc[0,0]=34)
# Out:
#   Cell In[43], line 5
#     data.to_excel('example.xlsx)
#                   ^
# SyntaxError: unterminated string literal (detected at line 5)
