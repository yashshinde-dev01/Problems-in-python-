# %%
s=set();
s.add(9);
print(s)

t={1,2,3,4}
print(t)
# Out:
# {9}
# {1, 2, 3, 4}

# %%
s={2,3,4,5,5,2,2}
max(s)
# min(s)
# Out:
# 5

# %%
# Que 1 ) WAP to remove an item from a set if present in between two set

# %%
s1={1,2,3,4,5}
s2={1,2,6,7,8}
s3=set()
for item in s1.copy():
    if item in s2:
        s1.remove(item)
print(s1)
# Out:
# {3, 4, 5}

# %%
# method -2
s1={1,2,3,4,5}
s2={1,2,6,7,8}
s1=s1-s2;
print(s1)
# Out:
# {3, 4, 5}

# %%
# que 2)WAP to check if two sets have no common elements

# %%
s1={1,2,3,4,5}
s2={1,2,6,7,8}
common=False;
for i in s1:
    if i in s2:
        common=True
if common==True:
    print("true")
else:
    print('false')
# Out:
# true

# %%
# QUE 3) WAP to find the missing number in a set

# %%
s1={11,12,13,14,15}
s2={11,13,14,15}
for r in s1:
    if r not in s2:
        print("missing item in s2 is:",r)
# for v in s2:
#     if v not in s1:
#         print("Misssing item in s1 is:",v)
# Out:
# missing item in s2 is: 12

# %%
# Que 4) W.A.P to find two numbers whose product is maximum among all numbers in a given set

# %%
s = {3, 5, 2, 9, 7}

nums = list(s)
max_product = 0

for i in range(len(nums)):
    for j in range(i+1, len(nums)):
        product = nums[i] * nums[j]
        
        if product > max_product:
            max_product = product
            num1 = nums[i]
            num2 = nums[j]

print("Numbers:", num1, num2)
print("Maximum product:", max_product)
# Out:
# Numbers: 7 9
# Maximum product: 63

# %%
# Que 5) WAP to find the third largest number in a set

# %%
st={1,2,3,4,93,90,92,91}
lar=0;
slar=-1;
thlar=-2;
for val in st:
    if val>lar:
        thlar=slar;
        slar=lar;
        lar=val;
        
print(thlar)
# Out:
# 91

# %%
# que 6) WAP to remove all a duplicate strings in a set and return the list

# %%
lst=["om","mohan","gedam","mohan","om"]
lst2=[]
l=set();
for itm in lst:
    if itm not in l:
        l.add(itm)
        lst2.append(itm);
print(lst2)
# Out:
# ['om', 'mohan', 'gedam']

# %%
# Que 7) WAP to find the common prefix in all string elements in a set

# %%
st={"helloYASH","helloOm","hellokrushna"}
def commonprefix(st):
    lst=list(st);
    prefix=lst[0];
    for itm in lst:
        while not itm.startswith(prefix):
            prefix=prefix[:-1];

            if prefix=="":
                return "";
    return prefix;

pre=commonprefix(st);
print(pre)
# Out:
# hello
