# %%
try:
    res=10/0
except ZeroDivisionError:
    print("cant divide by zero")
# Out:
# cant divide by zero

# %%
# Que-1) Impliment the program to handle following exception 
# i)0 division error 
# ii)file not found 
# iii)value error
# vi) type error
# v) index out of bound

# %%
try:
    res=10/0
except ZeroDivisionError:
    print("cant divide by zero")

# %%
try:
    file=open("unknown.txt",'r')
except FileNotFoundError:
    print("file not found")
# Out:
# file not found

# %%
try:
    a=int(2)
except ValueError:
    print("invalid!")
else:
    print(a)
finally:
    print("ok done")
# Out:
# 2
# ok done

# %%
try:
    add=10+"3"
except TypeError:
    print("can't added")
else:
    print(add)
# Out:
# can't added

# %%
try:
    lst=[1,2,3]
    i=int(input("enter a index"))
    lst[i]
except IndexError:
    print("Index is out of bound")
else:
    print(lst[i])
# Out:
# enter a index 5
# Index is out of bound

# %%
try:
    # b="a"+45;
    arr=[1,2,3]
    a=int(input("Enter a number a"))
    print(arr[a])
    file=open("exa.txt",'r')
    res=10/0
    b="a"+45;
except ZeroDivisionError:
    print("cant be divide by zero")
except FileNotFoundError:
    print("file is not availble")
except IndexError:
    print("index error")
except TypeError:
    print("Cant't be converted")
except ValueError:
    print("value is invalid")
# Out:
# Enter a number a 6
# index error
